# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
 
name_list = ['Monday','Tuesday','Friday','Sunday']
num_list = [1.5,0.6,7.8,6]
num_list1 = [1,2,3,1]
x =list(range(len(num_list)))
total_width, n = 0.8, 2
width = total_width / n
 
plt.bar(x, num_list, width=width, label='boy',fc = 'y')
for i in range(len(x)):
    x[i] = x[i] + width
plt.bar(x, num_list1, width=width, label='girl',tick_label = name_list,fc = 'r')
plt.legend()
plt.show()

# %%
import sqlite3
import csv

conn = sqlite3.connect('example_db')
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE CCDate_2021
    (Time TEXT, VisitorID TEXT, ExternalID INTEGER PRIMARY KEY, Role TEXT, Location TEXT, Link Title TEXT, Link Type TEXT, ContentInfo TEXT, URL TEXT)
''')
conn.commit()

with open('CCDate2018-2021-3-8.csv', 'r') as csvfile:
    CCDate_2021_Sql = csv.reader(csvfile, delimiter=',', quotechar='"')
    for row in CCDate_2021_Sql:
        print(row) # Check what we have...
        cursor.execute('''
            INSERT INTO CCDate_2021 (Time, VisitorID, ExternalID, Role, Location, Link Title, Link Type, ContentInfo, URL) VALUES (?,?,?,?,?,?,?,?,?)
        ''', (row[0], row[1], row[2], row[3], row[4], row[5], row[6], row[7], row[8])
conn.commit()

cursor.execute('''
    SELECT * from CCDate_2021
''')
cursor.fetchall()
                       
# CCDate_2021_Data = pd.read_csv("CCDate2018-2021-3-8.csv")
# Users2021_Data = pd.read_csv("Users2021-Origin.csv")
# CMC_2021_Data = pd.read_csv("CustomerMedicalConditions04Nov21.csv")

# %%
import sqlite3

conn = sqlite3.connect('example_db')
cursor = conn.cursor()

cursor.execute('''
    drop table if exists CMC_2021
''')
conn.commit()

cursor.execute('''
    CREATE TABLE CMC_2021
    (ExternalID TEXT, CleverCogsUserId TEXT, Gender TEXT, DateOfBirth TEXT, Age TEXT, StaffPlanConditions TEXT, CareSysCondition TEXT)
''')
conn.commit()

for x in range(len(CMC_2021_Data.index)):
    row_data=[]
    for y in range(7):
#         print(CMC_2021_Data.iloc[x,y])
        row_data.append(CMC_2021_Data.iloc[x,y])
    tuple_row = tuple(row_data)
    print(tuple_row)
    cursor.execute('''
    INSERT INTO CMC_2021 (ExternalID, CleverCogsUserId, Gender, DateOfBirth, Age, StaffPlanConditions, CareSysCondition) VALUES (?,?,?,?,?,?,?)
    ''', tuple_row)
    conn.commit()
    
cursor.execute('''
    SELECT * from CMC_2021
''')
cursor.fetchall()

print('done')

# %%
#检查数据
mylist = []
rowlen = len(CCDate_2021_Data.index)
a=1
for x in range(rowlen):
    mylist.append(CCDate_2021_Data.iloc[x,a])
mylist.sort()
print(mylist)

# %%
ExNull_list=[]
for x in range(len(CCDate_2021_Data_ClRole.index)):
    if CCDate_2021_Data.iloc[x,1] =='NULL':
        print(CCDate_2021_Data.iloc[x])
        ExNull_list.append(x)
CCDate_2021_Data_ClRole_ClEx=CCDate_2021_Data.drop(ExNull_list)
print('done')

# %%
#多年龄段饼图
# f, axes = plt.subplots(15, 15, figsize=(7, 7), sharex=True)
x=0
y=0
while x<130:
    a=CCDate_CMC_2021_inner[(CCDate_CMC_2021_inner['Age']>=x) & (CCDate_CMC_2021_inner['Age']<(x+10))]
    CSC_counts=a['CareSysCondition'].value_counts()
#     print(CSC_counts)
    plt.subplot(271+y)
    plt.pie(CSC_counts, labels = CSC_counts.index, startangle = 90, counterclock = False, autopct=make_autopct(CSC_counts));
    x+=10
    y+=1
# CSC_counts = CMC_2021_Data_OnlyID['CareSysCondition'].value_counts()
# plt.pie(CSC_counts, labels = CSC_counts.index, startangle = 90,
#         counterclock = False, autopct=make_autopct(CSC_counts));
plt.show()

# %%
#多年龄段柱状图

x=0
y=0


while x<130:
    a=CCDate_CMC_2021_inner[(CCDate_CMC_2021_inner['Age']>=x) & (CCDate_CMC_2021_inner['Age']<(x+10))]
    CSC_counts=a['CareSysCondition'].value_counts()
    list_len =list(range(len(CSC_counts)))
    total_width, n = 0.8, 2
    width = total_width / n
    plt.bar(list_len, CSC_counts, width=width, label='Male',tick_label = CSC_counts.index, fc = 'y')
    for i in range(len(list_len)):
        list_len[i] = list_len[i] + width
    x+=10
    
# plt.bar(list_len, CSC_counts, width=width, label='Female',fc = 'r')
# plt.bar(list_len, CSC_counts, width=width, label='Female',tick_label = Usage_amount_month_list,fc = 'r')
# print(Usage_amount_data_list_male)
# print(Usage_amount_data_list_female)



# plt.xlabel("Month (2021)")  #设置X轴Y轴名称  
# plt.ylabel("Usage amount") 

# for a,b in zip(range(len(Usage_amount_data_list_male)),Usage_amount_data_list_male):  #使用text显示数值 
#     plt.text(a, b+0.05, '%.0f' % b, ha='center', va='bottom',fontsize=10) 
    
# for a,b in zip(range(len(Usage_amount_data_list_female)),Usage_amount_data_list_female):  #使用text显示数值 
#     plt.text(a+0.4, b+0.05, '%.0f' % b, ha='center', va='bottom',fontsize=10) 

plt.legend()
plt.show()
print('down')

# %%
import numpy as np
import matplotlib.pyplot as plt


# Have colormaps separated into categories:
# http://matplotlib.org/examples/color/colormaps_reference.html
cmaps = [('Perceptually Uniform Sequential', [
            'viridis', 'plasma', 'inferno', 'magma']),
         ('Sequential', [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']),
         ('Sequential (2)', [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']),
         ('Diverging', [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']),
         ('Qualitative', [
            'Pastel1', 'Pastel2', 'Paired', 'Accent',
            'Dark2', 'Set1', 'Set2', 'Set3',
            'tab10', 'tab20', 'tab20b', 'tab20c']),
         ('Miscellaneous', [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg', 'hsv',
            'gist_rainbow', 'rainbow', 'jet', 'nipy_spectral', 'gist_ncar'])]


nrows = max(len(cmap_list) for cmap_category, cmap_list in cmaps)
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(cmap_category, cmap_list, nrows):
    fig, axes = plt.subplots(nrows=nrows)
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        pos = list(ax.get_position().bounds)
        x_text = pos[0] - 0.01
        y_text = pos[1] + pos[3]/2.
        fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps:
    plot_color_gradients(cmap_category, cmap_list, nrows)

plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# sns.set(rc={"figure.figsize": (6, 6)})

# %%
data = np.random.normal(size=(20, 8)) + np.arange(8) / 2  #生成数据
sns.boxplot(data=data,palette=sns.color_palette("Paired",8))#按照生成的颜色对应不同的分类
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Describe
# There are three files named `CCData2018-2021` `User2021` `CustomerMedicalConditions`.
#
# The data type of the three files is tabular.
#
# `CCData2018-2021` is the user's entertainment behavior dataset, and the data type is tabular. There are a total of 654915 rows of data, each row representing one user action. The entire data has 9 columns. All data is of string type. This file can use 'External ID' to link to `User2021` and `CustomerMedicalConditions`, and use 'Visiter ID' to link to `User2021`. There is data here going back to January 2018 until November 2021.
#
# `User2021` is the user information dataset, and the data type is tabular. There are a total of 3641 rows of data, each row representing one user information including the data on gender, where people live, and ages. The entire data has 6 columns. All data is of string type. This file can use 'External ID' to link to `CCData2018-2021` and `CustomerMedicalConditions`, and use 'Visiter ID' to link to `CCData2018-2021`. The data in this file only show the user still alive in 2021.
#
# `CustomerMedicalConditions` is the user health status dataset, and the data type is tabular. There are a total of 1312 rows of data, each row representing one user's basic information including the data on gender and their health conditions and ages. The entire data has 7 columns. All data is of string type. This file can use 'External ID' to link to `CCData2018-2021` and `User2021`. The data in this file only show the user still alive in 2021.
#
# In my group, we divide `CCData2018-2021` into 5 parts depending on the city-lockdown period. Firstly, we want to find out that in each period the relationship between activity and user features individually. And then in Assessment3, we can compare the difference among each period in a variety of aspects from everyone.

# %%
CMC_2021_Data = pd.read_csv("CustomerMedicalConditions04Nov21.csv")

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('CustomerMedicalConditions04Nov21.csv')
X = dataset.iloc[:, 3:5].values

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, max_iter = 300, n_init = 10, init = 'k-means++', random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-3608d6dcb775> in <module>
#       4 for i in range(1,11):
#       5     kmeans = KMeans(n_clusters = i, max_iter = 300, n_init = 10, init = 'k-means++', random_state = 0)
# ----> 6     kmeans.fit(X)
#       7     wcss.append(kmeans.inertia_)
#       8 plt.plot(range(1,11), wcss)
#
# /opt/conda/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     977             Fitted estimator.
#     978         """
# --> 979         X = self._validate_data(X, accept_sparse='csr',
#     980                                 dtype=[np.float64, np.float32],
#     981                                 order='C', copy=self.copy_x,
#
# /opt/conda/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
# ...

# %% [markdown]
# ## 2.2 Age feature of group with different Care System Conditions
# **Important**: From now the data I analysis is not all data from 2018 to 2021, but the period from **5th November 2020 to 6th January 2021**, which is the `Phase four: second national lockdown` and `Phase five: reintroducing a tier system` in [Coronavirus lockdown laws](https://commonslibrary.parliament.uk/research-briefings/cbp-9068/).
# ### Hypothesis:
# - There are some diseases that may have age feature. So depending on the type of disease, the age distribution of users may vary.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

CMC_data = pd.read_csv("CustomerMedicalConditions04Nov21.csv")
CC_data = pd.read_csv("CCDate_01.06.2021- 03.08.2021.csv")

# Cleaning data
# Why? -> this is because in medical data, in some cases, multiple rows are repeated for an External ID because there are different StaffPlanConditions for the same External ID.
# So, to analysis the age distribution for different medical conditions, every user(External ID) should only be counted for once.
data_18 = CMC_data.drop(CMC_data.index[CMC_data['Age'] < 18])  
data_18_DOB = data_18.dropna(axis = 0, subset = ["DateOfBirth"] )  
noID_data = data_18_DOB.drop_duplicates(subset=['ExternalID'], keep='first')

# for data in [CareSysCondtions], if they are NaN, change it to 'Unknown Condition' 
noCon_noID_data = noID_data.copy()
Cons_data = noCon_noID_data['CareSysCondition']
CountCon=0

for Cons in Cons_data:
    if pd.isnull(Cons):
        noCon_noID_data.iloc[CountCon,6] = 'Unknown Condition'
    CountCon += 1
    
# Use assertions to make sure the there is no repeating external ID, and all no null value
count = 0
for ID in noCon_noID_data['ExternalID']:
    for other_id in noCon_noID_data['ExternalID'][0:count]:
        assert ID != other_id, "One External ID should not appear more than once!"
    count += 1
for Cons in noCon_noID_data['CareSysCondition']:
    assert Cons != '', "There is still null!"
    
    
# Data being group by CareSysCondition, to explore the age distribution in each group(CareSysCondition)
group_condition = noCon_noID_data.groupby('CareSysCondition')

# to give an order for different'CareSysCondition' by the average age
avg_age = group_condition.agg({'Age':np.mean}).sort_values('Age')

# data visualization
plt.figure(figsize=(16,9),dpi=100)
sns.set(style='darkgrid',font_scale=1.2,palette='pastel')
sns.boxplot(x='CareSysCondition', y='Age', data=noCon_noID_data, order = avg_age.index)
plt.xticks(rotation=75,fontsize=10)
plt.yticks(fontsize=10)
plt.title('Age Distribution of groups with different Care System Condition',fontsize=20)
plt.show()

# %% [markdown]
# ### Key Fndings:
# - Groups with some Care System Condition has Age feature, which means that the Age Distribution of there groups is relatively concentrite, and without extreme Age value.(e.g. Group with Learning Difficulties, Epilepsy, Cerebral Palsy, Parkinsons, Arthritis...)
#
# Notes: This only shows the feature in CleverCogs users, but not the feature of all people with that condition.

# %% [markdown]
# ## 2.3 Activity Usage of Groups with Different Care System Condition
# ### Hypothesis:
# - Will `Activity Use Times` have correlation with users' `Care System Conditions`?

# %%
# For data cleaning part, the medical condition data should still be no repeat [External ID] and no null [CareSysCondtions]
# So Keep use the noCon_noID_data which has been cleaned.

#Merge data which same External ID
Time_Condition_data = pd.merge(noCon_noID_data, CC_data, on='ExternalID')
# drop group with unknown condition
Time_Condition_data_no_unknown = Time_Condition_data.loc[Time_Condition_data['CareSysCondition']!='Unknown Condition']

# To see the group with which condition contributes more in use Times
sns.set(style='darkgrid',palette='pastel')
plt.figure(figsize=(16,9),dpi=100)
plt.xticks(rotation=75)
plt.title("Activity Usage of Groups with different Care System Condition",fontsize=20)

# Use countplot and give an order by count activity use time
sns.countplot(x='CareSysCondition', data=Time_Condition_data_no_unknown, order = Time_Condition_data_no_unknown['CareSysCondition'].value_counts().index)
# Out:
# <AxesSubplot:title={'center':'Activity Usage of Groups with different Care System Condition'}, xlabel='CareSysCondition', ylabel='count'>

# %% [markdown]
# ### Key Findings:
# - Except group with unknown condition, groups with Cerebral Palsy contributes most in activities usage, then group with arthritis.
#
# Is that only because the total amount of users in these two groups is relatively high?
#
#
# —> for comparing, I make the figure below to show the Total Number of Users in Group with Different Care System Conditions.

# %%
Time_Condition_data = pd.merge(noCon_noID_data, CC_data, on='ExternalID')
# drop group with unknown condition
Time_Condition_data_no_unknown = Time_Condition_data.loc[Time_Condition_data['CareSysCondition']!='Unknown Condition']


Time_Condition_data_no_unknown_no_repeat = Time_Condition_data_no_unknown.drop_duplicates(subset=['ExternalID'], keep='first')


# To see the group with which condition contributes more in use Times
sns.set(style='darkgrid',palette='pastel')
plt.figure(figsize=(16,9),dpi=100)
plt.xticks(rotation=75)
plt.title("Total Number of Groups with different Care System Condition",fontsize=20)

# Use countplot and give an order by count activity use time
sns.countplot(x='CareSysCondition', data=Time_Condition_data_no_unknown_no_repeat, order = Time_Condition_data_no_unknown_no_repeat['CareSysCondition'].value_counts().index)
# Out:
# <AxesSubplot:title={'center':'Total Number of Groups with different Care System Condition'}, xlabel='CareSysCondition', ylabel='count'>

# %% [markdown]
# ### Key Findings:
# - For group with Cerebral Palsy and Arthritis, they don't have the most amount of users(ranks 4th and 12th), but they contributes most in usage (ranks 1st and 2nd).
# - For group with Elderly Care/Support, they have the most amount of users(ranks 1st), but their contribution in usage ranks 10th.

# %% [markdown]
# ## 2.4 Gender Contribution in Usage of groups with different Care System Conditions
# ### Hypothesis:
# - I want to explore Gender Contribution in Usage of Groups with different CareSysConditon, to see is there any correlation of `Usage`, `Gender` and `CareSysCondition`.

# %%
# The figure above could be directly used by adding [Gender] as hue, to see which gender contributes more.
sns.set(style='darkgrid',font_scale=1.2,palette='pastel')
plt.figure(figsize=(16,9),dpi=100)
plt.xticks(rotation=75)
plt.title("Usage of Groups with different Care System Condition (Classified by Gender)",fontsize=20)
sns.countplot(x='CareSysCondition', data=Time_Condition_data_no_unknown, hue='Gender', order = Time_Condition_data_no_unknown['CareSysCondition'].value_counts().index)
# Out:
# <AxesSubplot:title={'center':'Usage of Groups with different Care System Condition (Classified by Gender)'}, xlabel='CareSysCondition', ylabel='count'>

# %% [markdown]
# ### Key Finding:
# - The female with Cerebral palsy significantly contributes more than the male.
# ——> I found such an uneven gender contribution ratio in many other groups, such as Group with Epilepsy, Lifelong Mobility Issue, and Arthritis.
#
# However, one thing that should be check is, is that because there are more females with Cerebral palsy than males with Cerebral palsy among users?
#
#
# So in the next step, I use a Pie Chart to check the `Gender Ratio`(in amount of users) of Groups with different Care System Conditions.
#
# Also, to see the `Gender Contribution ratio`(in amount of Usage) more clearly, I use an other pie chart to show the Gender Contribution in Activity Usage of group with differnet conditions.

# %%
# group_condition is Data being group by CareSysCondition which has been used before.
# See the structure of group_condition:
for condition, group  in group_condition:
    print(condition) #all data has been group by Condition and divided into several new dataframe
    print(group)
# Out:
# Addiction Issues
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 939         8785              4494      M   1978/2/27  43.0
# 1015        8917              4901      F   1976/9/19  45.0
# 1113        9093              5083      M   1961/2/18  60.0
# 1151        9145              5168      F   1961/9/19  60.0
# 1263        9397              5457      F   1965/6/12  56.0
#
#      StaffPlanConditions  CareSysCondition
# 939                  NaN  Addiction Issues
# 1015                 NaN  Addiction Issues
# 1113                 NaN  Addiction Issues
# 1151                 NaN  Addiction Issues
# 1263                 NaN  Addiction Issues
# Amputee
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 22          4727               936      F   1932/7/26  89.0
# 38          4748               910      F   1935/3/18  86.0
# 309         5653              1580      M    1943/4/3  78.0
# 773         8296              4014      M   1934/5/15  87.0
# 835         8440                 0      M   1961/4/12  60.0
# 866         8636              2396      M   1961/1/28  60.0
# 933         8772              4427      M   1980/5/29  41.0
# 999         8888              4867      F   1970/6/14  51.0
# 1111        9089              5078      M    1958/3/6  63.0
# 1112        9090              5079      F   1959/3/26  62.0
# 1127        9114              5119      F   1950/5/19  71.0
# 1184        9210              2395      M    1961/7/8  60.0
# 1222        9281              5377      F    1953/4/8  68.0
#
#      StaffPlanConditions CareSysCondition
# 22                   NaN          Amputee
# 38                   NaN          Amputee
# 309                  NaN          Amputee
# 773                  NaN          Amputee
# 835                  NaN          Amputee
# 866                  NaN          Amputee
# 933                  NaN          Amputee
# 999                  NaN          Amputee
# 1111                 NaN          Amputee
# 1112                 NaN          Amputee
# 1127                 NaN          Amputee
# 1184                 NaN          Amputee
# 1222                 NaN          Amputee
# Arthritis
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 66          4782              1074      M   1928/9/12  93.0
# 75          5057               821      F   1924/10/3  97.0
# 78          5060               954      F   1932/7/28  89.0
# 96          5103               935      M    1946/4/5  75.0
# 126         5142              1071      F   1933/1/21  88.0
# 134         5150              1213      F   1933/3/27  88.0
# 174         5210              1343      F   1949/1/16  72.0
# 179         5235              1092      F   1924/9/10  97.0
# 202         5396              1305      M    1954/6/4  67.0
# 245         5533              1418      F   1952/2/25  69.0
# 258         5545              1467      F  1962/10/19  59.0
# 308         5652              1581      M    1933/9/4  88.0
# 424         5882              1837      F   1923/5/28  98.0
# 476         5995              2142      F   1945/4/10  76.0
# 683         7942              2608      M  1942/11/25  79.0
# 757         8244              2949      M   1942/3/14  79.0
# 763         8254              2965      F    1929/5/8  92.0
# 804         8356                 0      F   1940/5/21  81.0
# 991         8874              4851      F   1930/8/16  91.0
# 995         8881              4866      F   1946/3/21  75.0
# 996         8883              4860      F  1999/10/10  22.0
# 1290        9464              5577      F    1953/4/9  68.0
# 1291        9465              5578      M   1954/6/29  67.0
#
#      StaffPlanConditions CareSysCondition
# 66                   NaN        Arthritis
# 263                                                 NaN   Cerebral Palsy
# 338                                                 NaN   Cerebral Palsy
# 341                                                 NaN   Cerebral Palsy
# 490                                                 NaN   Cerebral Palsy
# 494                                                 NaN   Cerebral Palsy
# 510                                                 NaN   Cerebral Palsy
# 606                                                 NaN   Cerebral Palsy
# 609                                                 NaN   Cerebral Palsy
# 612   Deaf                                          ...   Cerebral Palsy
# 619   Cerebal Palsy                                 ...   Cerebral Palsy
# 621                                                 NaN   Cerebral Palsy
# 662   Cerebal Palsy                                 ...   Cerebral Palsy
# 781   Arthitis                                      ...   Cerebral Palsy
# 816                                                 NaN   Cerebral Palsy
# 892                                                 NaN   Cerebral Palsy
# 959                                                 NaN   Cerebral Palsy
# 994                                                 NaN   Cerebral Palsy
# 1000                                                NaN   Cerebral Palsy
# 1058                                                NaN   Cerebral Palsy
# 1140  Cerebal Palsy                                 ...   Cerebral Palsy
# 1192  Cerebal Palsy                                 ...   Cerebral Palsy
# 1203                                                NaN   Cerebral Palsy
# 1208                                                NaN   Cerebral Palsy
# 1223                                                NaN   Cerebral Palsy
# 1224                                                NaN   Cerebral Palsy
# 1230                                                NaN   Cerebral Palsy
# 1235  Cerebal Palsy                                 ...   Cerebral Palsy
# 1266                                                NaN   Cerebral Palsy
# 1268                                                NaN   Cerebral Palsy
# Dementia
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 2           4706              1128      F   1931/2/25  90.0
# 6           4710               807      F   1937/1/21  84.0
# 8           4712               811      F   1929/5/10  92.0
# 12          4716              1130      F   1929/7/22  92.0
# 16          4720              1072      F   1934/8/13  87.0
# ...          ...               ...    ...         ...   ...
# 1142        9138              5157      F   1932/2/22  89.0
# 1150        9144              5167      U  1949/12/11  72.0
# 1167        9182              5216      F    1935/3/3  86.0
# 1185        9211              5258      F    1940/5/4  81.0
# 1287        9453              5563      M   1956/3/26  65.0
#
#                                     StaffPlanConditions CareSysCondition
# 2                                                   NaN         Dementia
# 6                                                   NaN         Dementia
# 8                                                   NaN         Dementia
# 12                                                  NaN         Dementia
# 16                                                  NaN         Dementia
# ...                                                 ...              ...
# 1142  Alzheimers                                    ...         Dementia
# 1150                                                NaN         Dementia
# 1167                                                NaN         Dementia
# 1185                                                NaN         Dementia
# 1287                                                NaN         Dementia
#
# [112 rows x 7 columns]
# Diabetes
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 17          4721               865      F   1932/8/11  89.0
# 116         5127              1009      M   1967/4/29  54.0
# 243         5531              1443      M   1932/10/8  89.0
# 406         5820              1797      M   1959/11/5  62.0
# 519         6167              2215      F  1933/12/20  88.0
# 588         7313              2414      F    1942/8/7  79.0
# 599         7738              2128      M   1945/8/16  76.0
# 858         8510              4302      M   1938/5/16  83.0
# 899         8676                 0      M   1932/2/24  89.0
# 904         8686                 0      F   1940/8/29  81.0
# 942         8792              4628      F   1935/4/22  86.0
# 979         8843              4804      M    1938/5/4  83.0
# 988         8866              4837      M   1966/2/27  55.0
# 1047        8988              4973      M    1976/6/8  45.0
# 1061        9003              4988      M    1946/4/3  75.0
# 1066        9008              4993      F  1956/12/14  65.0
# 1115        9097              5098      M    1993/9/4  28.0
# 1182        9209              5255      F  1948/12/23  73.0
# 1272        9408              5480      M   1944/8/25  77.0
#
#                                     StaffPlanConditions CareSysCondition
# 17                                                  NaN         Diabetes
# 116                                                 NaN         Diabetes
# 243                                                 NaN         Diabetes
# 406                                                 NaN         Diabetes
# 519                                                 NaN         Diabetes
# 588                                                 NaN         Diabetes
# 599                                                 NaN         Diabetes
# 858                                                 NaN         Diabetes
# 899                                                 NaN         Diabetes
# 904                                                 NaN         Diabetes
# 942                                                 NaN         Diabetes
# 979                                                 NaN         Diabetes
# 988                                                 NaN         Diabetes
# 1047                                                NaN         Diabetes
# 1061                                                NaN         Diabetes
# 1066                                                NaN         Diabetes
# 1115                                                NaN         Diabetes
# 1182  Hearing Impairment                            ...         Diabetes
# 1272                                                NaN         Diabetes
# Down Syndrome
#      ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 138        5154               773      F  1979/12/31  42.0
# 533        6202              2298      F    1923/3/2  98.0
#
#     StaffPlanConditions CareSysCondition
# 138                 NaN    Down Syndrome
# 533                 NaN    Down Syndrome
# Elderly Care/Support
#       ExternalID  CleverCogsUserId Gender DateOfBirth    Age  \
# 5           4709               938      F  1925/11/28   96.0
# 13          4717              1121      F  1917/10/28  104.0
# 15          4719               768      F   1937/9/18   84.0
# 19          4724               928      F   1928/1/11   93.0
# 24          4729               761      F    1923/8/9   98.0
# ...          ...               ...    ...         ...    ...
# 1269        9404              5468      F   1944/5/19   77.0
# 1282        9423              1821      F   1949/3/18   72.0
# 1286        9427              5517      U  1936/11/19   85.0
# 1300        9570              5633      F   1927/9/18   94.0
# 1303        9578              5648      M   1947/8/13   74.0
#
#      StaffPlanConditions      CareSysCondition
# 5                    NaN  Elderly Care/Support
# 13                   NaN  Elderly Care/Support
# 15                   NaN  Elderly Care/Support
# 19                   NaN  Elderly Care/Support
# 24                   NaN  Elderly Care/Support
# ...                  ...                   ...
# 1269                 NaN  Elderly Care/Support
# 1282                 NaN  Elderly Care/Support
# 1286                 NaN  Elderly Care/Support
# 1300                 NaN  Elderly Care/Support
# 1303                 NaN  Elderly Care/Support
#
# [261 rows x 7 columns]
# Epilepsy
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 9           4713               683      F   1960/5/28  61.0
# 47          4760               689      M   1979/7/15  42.0
# 55          4770               690      M  1963/12/14  58.0
# 94          5101              1002      M   1945/4/16  76.0
# 117         5129               812      F   1948/2/20  73.0
# 192         5341               684      M    1967/8/8  54.0
# 254         5540                 0      M  1962/10/20  59.0
# 257         5542              1425      M   1963/5/30  58.0
# 485         6005              2056      F   1987/11/2  34.0
# 725         8199              2895      F    1988/8/5  33.0
# 874         8645              2937      M    1976/5/6  45.0
# 897         8674              4329      F    1953/1/7  68.0
# 965         8825              4778      F   1973/7/18  48.0
# 1252        9374              5328      M   1970/9/30  51.0
#
#                                     StaffPlanConditions CareSysCondition
# 9                                                   NaN         Epilepsy
# 47                                                  NaN         Epilepsy
# 55                                                  NaN         Epilepsy
# 94                                                  NaN         Epilepsy
# 117                                                 NaN         Epilepsy
# 192   Epilepsy                                      ...         Epilepsy
# 254                                                 NaN         Epilepsy
# 257   Epilepsy                                      ...         Epilepsy
# 485                                                 NaN         Epilepsy
# 725   Epilepsy                                      ...         Epilepsy
# 874                                                 NaN         Epilepsy
# 897                                                 NaN         Epilepsy
# 965                                                 NaN         Epilepsy
# 1252  Epilepsy                                      ...         Epilepsy
# Huntington's
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
#
# 260                                                 NaN  Learning Difficulties
# 354                                                 NaN  Learning Difficulties
# 363                                                 NaN  Learning Difficulties
# 486   Visual Impairment                             ...  Learning Difficulties
# 585                                                 NaN  Learning Difficulties
# 607                                                 NaN  Learning Difficulties
# 658                                                 NaN  Learning Difficulties
# 711                                                 NaN  Learning Difficulties
# 791                                                 NaN  Learning Difficulties
# 826                                                 NaN  Learning Difficulties
# 863                                                 NaN  Learning Difficulties
# 865                                                 NaN  Learning Difficulties
# 879                                                 NaN  Learning Difficulties
# 881                                                 NaN  Learning Difficulties
# 924                                                 NaN  Learning Difficulties
# 929                                                 NaN  Learning Difficulties
# 931                                                 NaN  Learning Difficulties
# 975                                                 NaN  Learning Difficulties
# 1004                                                NaN  Learning Difficulties
# 1014                                                NaN  Learning Difficulties
# 1026                                                NaN  Learning Difficulties
# 1052                                                NaN  Learning Difficulties
# 1107                                                NaN  Learning Difficulties
# 1123                                                NaN  Learning Difficulties
# 1187                                                NaN  Learning Difficulties
# 1228                                                NaN  Learning Difficulties
# 1232                                                NaN  Learning Difficulties
# 1260                                                NaN  Learning Difficulties
# 1265                                                NaN  Learning Difficulties
# 1301                                                NaN  Learning Difficulties
# Lifelong Mobility Issues
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 175         5211              1347      M   1981/9/12  40.0
# 331         5682              1572      M   1985/5/29  36.0
# 333         5684              1574      M  1946/10/12  75.0
# 346         5709              1613      F  1964/12/31  57.0
# 349         5713              1617      M   1970/4/27  51.0
# 352         5716              1620      F   1939/9/19  82.0
# 358         5727              1631      M   1936/6/24  85.0
# 359         5728              1632      M  1959/11/19  62.0
# 431         5903              2283      F   1942/9/14  79.0
# 547         6233              2331      M    1953/2/4  68.0
# 722         8185              2849      M   1980/3/20  41.0
# 805         8357              4091      M   1956/5/12  65.0
# 888         8660              4233      M   1959/2/14  62.0
# 894         8670              4324      F   1978/10/7  43.0
# 982         8849              4815      F   1963/9/27  58.0
# 992         8875              4852      F   1971/9/19  50.0
# 1007        8908              4887      M    1953/6/5  68.0
# 1020        8922              4906      F   1975/7/19  46.0
# 1059        9001              4986      F   1950/11/4  71.0
# 1067        9009              4994      F   1973/9/14  48.0
# 1071        9013              4998      F   1998/3/10  23.0
# 1076        9018              5003      F   1945/1/29  76.0
# 1082        9024              5012      M   1969/6/15  52.0
# 1099        9066              5053      M   1935/3/20  86.0
# 1100        9067              5054      M   1934/6/16  87.0
# 1121        9104              5106      U   1943/2/15  78.0
# 1251        9372              5376      M    1952/1/9  69.0
#
#                                     StaffPlanConditions  \
# 175                                                 NaN
# 331                                                 NaN
# 333                                                 NaN
# 346   Spina Bifida                                  ...
# 349                                                 NaN
# 352                                                 NaN
# 358                                                 NaN
# 359   Visual Impairment                             ...
# 431                                                 NaN
# 547                                                 NaN
# 722                                                 NaN
# 805                                                 NaN
# 888                                                 NaN
# 894                                                 NaN
# 982                                                 NaN
# 992                                                 NaN
# 1007                                                NaN
# 1020                                                NaN
# 1059                                                NaN
# 1067                                                NaN
# 1071                                                NaN
# 1076                                                NaN
# 770         8289              4005      F   1977/11/7  44.0
# 807         8362              4098      F    1941/7/2  80.0
# 961         8818              4770      F    1969/8/1  52.0
# 998         8886              4856      M   1966/9/18  55.0
# 1006        8907              4886      U    1958/8/1  63.0
# 1064        9006              4991      F  1972/11/12  49.0
# 1162        9171              5206      F   1975/2/17  46.0
# 1163        9173              5208      F   1962/9/25  59.0
# 1188        9229              5375      F    1968/2/4  53.0
# 1206        9268              5296      M   1976/7/26  45.0
# 1210        9277              5308      F   1976/5/27  45.0
# 1234        9323              5290      F  1954/12/10  67.0
#
#                                     StaffPlanConditions    CareSysCondition
# 14                                                  NaN  Multiple Sclerosis
# 28                                                  NaN  Multiple Sclerosis
# 51                                                  NaN  Multiple Sclerosis
# 102                                                 NaN  Multiple Sclerosis
# 181                                                 NaN  Multiple Sclerosis
# 194   Multiple Sclerosis                            ...  Multiple Sclerosis
# 195                                                 NaN  Multiple Sclerosis
# ...
# 1064                                                NaN  Multiple Sclerosis
# 1162                                                NaN  Multiple Sclerosis
# 1163                                                NaN  Multiple Sclerosis
# 1188                                                NaN  Multiple Sclerosis
# 1206                                                NaN  Multiple Sclerosis
# 1210  Brain Injury                                  ...  Multiple Sclerosis
# 1234                                                NaN  Multiple Sclerosis
# Muscular Dystrophy
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 312         5658              1510      F    1965/3/5  56.0
# 488         6008              1864      M   1964/5/17  57.0
# 777         8300              4019      M    1922/4/8  99.0
# 1016        8918              4902      M   1994/11/7  27.0
#
#      StaffPlanConditions    CareSysCondition
# 312                  NaN  Muscular Dystrophy
# 488                  NaN  Muscular Dystrophy
# 777                  NaN  Muscular Dystrophy
# 1016                 NaN  Muscular Dystrophy
# OCD
#      ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 867        8637              2418      F   1971/3/20  50.0
# 923        8707              4370      F   1967/6/22  54.0
#
#     StaffPlanConditions CareSysCondition
# 867                 NaN              OCD
# 923                 NaN              OCD
# Parkinsons
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 88          5084              1103      M  1939/11/10  82.0
# 91          5098              1001      M   1940/8/10  81.0
# 121         5133              1111      F  1942/11/28  79.0
# 218         5464              1316      M  1931/12/31  90.0
# 261         5549              1471      M   1923/9/26  98.0
# 305         5649              1819      M  1950/10/30  71.0
# 328         5679              1569      F    1949/8/5  72.0
# 329         5680              1570      F    1941/3/6  80.0
# 393         5806              1784      F    1931/5/2  90.0
# 429         5893              1849      M   1928/3/18  93.0
# 647         7861              2501      M   1939/3/18  82.0
# 652         7871              2511      M   1947/2/21  74.0
# 679         7932              2593      M   1938/8/15  83.0
# 723         8195              2864      M   1948/7/11  73.0
# 803         8355                 0      M   1935/5/29  86.0
# 889         8661              4236      F   1945/3/16  76.0
# 930         8724                 0      F   1958/9/24  63.0
# 1022        8924              4908      F   1942/2/12  79.0
# 1074        9016              5001      M    1949/1/7  72.0
# 1103        9076              5063      M    1964/6/7  57.0
#
#      StaffPlanConditions CareSysCondition
# 88                   NaN       Parkinsons
# 91                   NaN       Parkinsons
# 121                  NaN       Parkinsons
# 218                  NaN       Parkinsons
# 261                  NaN       Parkinsons
# 305                  NaN       Parkinsons
# 328                  NaN       Parkinsons
# 329                  NaN       Parkinsons
# 393                  NaN       Parkinsons
# 429                  NaN       Parkinsons
# 647                  NaN       Parkinsons
# 652                  NaN       Parkinsons
# 679                  NaN       Parkinsons
# 723                  NaN       Parkinsons
# 803                  NaN       Parkinsons
# 889                  NaN       Parkinsons
# 930                  NaN       Parkinsons
# 1022                 NaN       Parkinsons
# 1074                 NaN       Parkinsons
# 1103                 NaN       Parkinsons
# Progressive Supranuclear Palsy
#      ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 145        5165               874      M   1971/5/24  50.0
#
#     StaffPlanConditions                CareSysCondition
# 145                 NaN  Progressive Supranuclear Palsy
# Spina Bifida
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 0           4703               685      F    1965/7/4  56.0
# 73          5055               893      F  1965/11/29  56.0
# 99          5106               753      M  1969/11/24  52.0
# 182         5255               925      M   1990/2/10  31.0
# 186         5293               625      M   1969/9/23  52.0
# 189         5335               901      M   1968/1/22  53.0
# 269         5561              1481      M    1970/3/3  51.0
# 270         5562              1341      F   1940/5/24  81.0
# 511         6162              2207      M   1964/8/28  57.0
# 572         6279              2377      F    1951/3/9  70.0
# 615         7798              1756      F   1978/2/24  43.0
# 622         7812              1729      F   1966/5/11  55.0
# 626         7813              1757      F   1972/2/17  49.0
# 667         7898              2538      F  1981/11/21  40.0
# 955         8811              4756      M   1964/12/6  57.0
# 1154        9148              5171      F   1967/10/3  54.0
# 1288        9457              5567      M    1966/5/1  55.0
# 1296        9561              5624      F  1972/10/11  49.0
#
#                                     StaffPlanConditions CareSysCondition
# 0                                                   NaN     Spina Bifida
# 73                                                  NaN     Spina Bifida
# 99                                                  NaN     Spina Bifida
# 182                                                 NaN     Spina Bifida
# 186                                                 NaN     Spina Bifida
# 189                                                 NaN     Spina Bifida
# 269                                                 NaN     Spina Bifida
# 270                                                 NaN     Spina Bifida
# 511                                                 NaN     Spina Bifida
# 572                                                 NaN     Spina Bifida
# 615   Skin Issues                                   ...     Spina Bifida
# 622   Incontinence                                  ...     Spina Bifida
# 626   Skin Issues                                   ...     Spina Bifida
# 667   Physical Injury                               ...     Spina Bifida
# 955                                                 NaN     Spina Bifida
# 1154                                                NaN     Spina Bifida
# 1288                                                NaN     Spina Bifida
# 1296  Spina Bifida                                  ...     Spina Bifida
# Spinal Injury
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 197         5384              1100      M    1965/8/5  56.0
# 337         5694              1593      F   1992/6/25  29.0
# 372         5760              1344      M    1969/2/5  52.0
# 900         8680                 0      M  1969/11/20  52.0
# 937         8780              4456      M  1969/11/20  52.0
# 997         8884              4862      F   1959/10/8  62.0
# 1018        8920              4904      M    1985/4/9  36.0
# 1190        9241              5294      M   1973/12/2  48.0
#
#                                     StaffPlanConditions CareSysCondition
# 197   Spinal Injury                                 ...    Spinal Injury
# 337                                                 NaN    Spinal Injury
# 372                                                 NaN    Spinal Injury
# 900                                                 NaN    Spinal Injury
# 937                                                 NaN    Spinal Injury
# 997                                                 NaN    Spinal Injury
# 1018                                                NaN    Spinal Injury
# 1190                                                NaN    Spinal Injury
# Stroke
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 32          4738               921      F   1955/3/23  66.0
# 60          4775               743      M   1935/10/5  86.0
# 187         5300               694      M    1985/8/2  36.0
# 190         5339               704      F   1945/4/15  76.0
# 214         5460              1309      F   1955/6/11  66.0
# 229         5475              1352      M   1967/6/23  54.0
# 299         5639              1587      M  1943/11/24  78.0
# 301         5645              1585      M    1951/3/8  70.0
# 306         5650              1586      F   1945/4/24  76.0
# 307         5651              1583      F   1928/3/21  93.0
# 326         5677              1567      M   1955/10/5  66.0
# 335         5691              1820      M   1947/4/25  74.0
# 360         5730              1633      F    1969/7/3  52.0
# 365         5743              1645      M    1962/6/5  59.0
# 373         5776              1688      F    1951/4/8  70.0
# 391         5804              1782      F   1934/1/19  87.0
# 415         5850              1724      F   1943/5/11  78.0
# 466         5970              2122      F   1999/7/15  22.0
# 473         5992              2139      M   1974/8/15  47.0
# 478         5997              2144      M  1950/12/28  71.0
# 492         6034              1875      M    1953/2/2  68.0
# 514         6165              2210      M   1969/10/4  52.0
# 521         6171              2221      M   1966/1/19  55.0
# 594         7733              2438      M   1931/9/26  90.0
# 644         7851              2491      F   2000/7/18  21.0
# 759         8247              2953      M   1928/6/22  93.0
# 801         8347                 0      M   1967/6/20  54.0
# 903         8685                 0      F   1932/1/24  89.0
# 1019        8921              4905      F  1980/10/28  41.0
# 1093        9055              5041      F    1959/7/4  62.0
# 1175        9198              5238      M    1962/3/7  59.0
# 1176        9199              5242      M   1974/9/29  47.0
# 1177        9200              5243      M   1957/4/15  64.0
# 1284        9425              5515      F    1970/9/3  51.0
#
#                                     StaffPlanConditions CareSysCondition
# 32                                                  NaN           Stroke
# 60                                                  NaN           Stroke
# 187                                                 NaN           Stroke
# 190                                                 NaN           Stroke
# 214                                                 NaN           Stroke
# 229                                                 NaN           Stroke
# 299                                                 NaN           Stroke
# 301                                                 NaN           Stroke
# 306                                                 NaN           Stroke
# 307                                                 NaN           Stroke
# 326                                                 NaN           Stroke
# 335                                                 NaN           Stroke
# 360                                                 NaN           Stroke
# 365                                                 NaN           Stroke
# 373                                                 NaN           Stroke
# 391                                                 NaN           Stroke
# 415                                                 NaN           Stroke
# 466                                                 NaN           Stroke
# 473                                                 NaN           Stroke
# 478                                                 NaN           Stroke
# 492   Brain Injury                                  ...           Stroke
# 514   Hearing Impairment                            ...           Stroke
# 521                                                 NaN           Stroke
# 594                                                 NaN           Stroke
# 644                                                 NaN           Stroke
# 759                                                 NaN           Stroke
# 801                                                 NaN           Stroke
# 903                                                 NaN           Stroke
# 1019                                                NaN           Stroke
# 1093                                                NaN           Stroke
# 1175                                                NaN           Stroke
# 1176                                                NaN           Stroke
# 1177                                                NaN           Stroke
# 1284                                                NaN           Stroke
# Unknown Condition
#       ExternalID  CleverCogsUserId Gender DateOfBirth   Age  \
# 4           4708               784      F  1931/12/20  90.0
# 10          4714               860      F   1949/5/28  72.0
# 11          4715              1122      F   1944/9/26  77.0
# 18          4722               826      F   1934/10/4  87.0
# 21          4726              1112      F  1932/10/16  89.0
# ...          ...               ...    ...         ...   ...
# 1305        9582              5652      F   1942/1/26  79.0
# 1306        9586              5656      F    1932/4/9  89.0
# 1307        9594              4060      M   1948/10/8  73.0
# 1308        9600              5670      M   1952/11/2  69.0
# 1310        9605              5679      F   1967/5/19  54.0
#
#                                     StaffPlanConditions   CareSysCondition
# 4                                                   NaN  Unknown Condition
# 10                                                  NaN  Unknown Condition
# 11                                                  NaN  Unknown Condition
# 18                                                  NaN  Unknown Condition
# 21                                                  NaN  Unknown Condition
# ...                                                 ...                ...
# 1305                                                NaN  Unknown Condition
# 1306  Dementia                                      ...  Unknown Condition
# 1307  Multiple Sclerosis                            ...  Unknown Condition
# 1308                                                NaN  Unknown Condition
# 1310                                                NaN  Unknown Condition
#
# [325 rows x 7 columns]
# Visual Impairment
#      ExternalID  CleverCogsUserId Gender DateOfBirth    Age  \
# 61         4776               866      M    1931/5/1   90.0
# 76         5058               763      F   1920/7/13  101.0
# 268        5559              1480      F   1950/4/22   71.0
# 524        6181              2265      M  1960/12/13   61.0
# 617        7801              1728      F   1950/4/14   71.0
# 674        7903              2554      M   1928/5/23   93.0
# 691        7955              2618      F   1942/7/27   79.0
# 812        8371                 0      F    1977/4/5   44.0
# 887        8659              4234      M   1962/9/25   59.0
# 895        8672                 0      F   1937/12/1   84.0
#
#                                    StaffPlanConditions   CareSysCondition
# 61                                                 NaN  Visual Impairment
# 76                                                 NaN  Visual Impairment
# 268                                                NaN  Visual Impairment
# 524                                                NaN  Visual Impairment
# 617  Hearing Impairment                            ...  Visual Impairment
# 674                                                NaN  Visual Impairment
# 691                                                NaN  Visual Impairment
# 812                                                NaN  Visual Impairment
# 887                                                NaN  Visual Impairment
# 895                                                NaN  Visual Impairment

# %%
# Creat Pie chart for Gender Contribution in Usage with different Care System Condition
# with loop
for name,group in Time_Condition_data_no_unknown.groupby('CareSysCondition'):
    count_f = (group.loc[group['Gender'] == 'F']).shape[0]
    count_m = (group.loc[group['Gender'] == 'M']).shape[0]
    count_u = (group.loc[group['Gender'] == 'U']).shape[0]
    gender_name = ['Female','Male','Unknown']
    gender_size_count = [count_f,count_m, count_u]
    plt.figure(figsize=(2,2), dpi=75)
    plt.pie(gender_size_count, labels=gender_name, autopct="%1.2f%%", wedgeprops = {'width' : 0.4})
    plt.legend(bbox_to_anchor = (1,1))
    plt.title("Gender Contribution in Activity Usage of group with " + name, fontsize=10, y=1.08) # Give some space between Title and fig
    plt.axis('equal')
    plt.show()

# %%
# Creat pie chart of Gender for groups with different Care System Condition
# with Loop
for name,group in noCon_noID_data_no_unknown.groupby('CareSysCondition'):
    count_f = (group.loc[group['Gender'] == 'F']).shape[0]
    count_m = (group.loc[group['Gender'] == 'M']).shape[0]
    count_u = (group.loc[group['Gender'] == 'U']).shape[0]
    gender_name = ['Female','Male','Unknown']
    gender_size_count = [count_f,count_m, count_u]
    plt.figure(figsize=(2,2), dpi=75)
    plt.pie(gender_size_count, labels=gender_name, autopct="%1.2f%%", wedgeprops = {'width' : 0.4})
    plt.legend(bbox_to_anchor = (1,1))
    plt.title("Gender Ratio of group with " + name, fontsize=10, y=1.08) # Give some space between Title and fig
    plt.axis('equal')
    plt.show()

# %% [markdown]
# ### Key Findings:
# - Care System Condition will affact the Gender Contribution Ratio in Usage:
#     - For group with `Cerebral Palsy`：There is 60.9% Male and 38.1% female in that group; However, the contribution of usage of Male is far over 60.9%, which is 94.58%. -> This shows that in group with Cerebral Palsy, the average contribution of each male is more than female's.
#
#     - For group with `Arthritis`：There is 30.43% Male and 69.57% female in that group; However, the contribution of usage of female is 74.24%, and that of male is 25.73. -> This shows that in group with Arthritis, the female is actively contributed in usage while males never contributed.
#
#     - For group with `Brain Injury`：There is 58.82% Male and 38.24% female in that group; The contribution of usage of female is 100%. -> This shows that in group with Brain Injury, the female and male motivation of usage contributino is nearly the same level.
#
#     - for group with ……

# %% [markdown]
# ## 2.5 Group (with different Care System Condition)'s Contribution in 'Care'-related Activities
# ### Hypothesis:
# - Users with what `CareSysConditon` click more on `LinkTitle` `with the keyword 'Care'`? （which might refer to a greater concern for one's CARE situation）

# %%
Care_data = Time_Condition_data_no_unknown.loc[(Time_Condition_data['LinkTitle']=='My Care')| (Time_Condition_data['LinkTitle']=='My Care Team') |(Time_Condition_data['LinkTitle']== 'Care Website')]

sns.set(style='darkgrid',palette='pastel')
plt.figure(figsize=(16,9),dpi=100)
plt.xticks(rotation=75)
plt.title("Usage(Care-related) Contribution of Groups with Differnet CareSysCondition ",fontsize=20)
# Use countplot and give an order by count activity use time
sns.countplot(x='CareSysCondition', data=Care_data, order = Care_data['CareSysCondition'].value_counts().index)
# Out:
# <AxesSubplot:title={'center':'Usage(Care-related) Contribution of Groups with Differnet CareSysCondition '}, xlabel='CareSysCondition', ylabel='count'>

# %%
Care_data = Time_Condition_data_no_unknown.loc[(Time_Condition_data['LinkTitle']=='Blackwood COVID-19 Letter')| (Time_Condition_data['LinkTitle']=='COVID-19 Aberdeen') |(Time_Condition_data['LinkTitle']== 'COVID-19 Dundee')|(Time_Condition_data['LinkTitle']== 'COVID-19 Info - Aberdeen Local Links')|(Time_Condition_data['LinkTitle']== 'COVID-19 Info - Dundee Local Links')|(Time_Condition_data['LinkTitle']== 'COVID-19 Information')]

sns.set(style='darkgrid',palette='pastel')
plt.figure(figsize=(16,9),dpi=100)
plt.xticks(rotation=75)
plt.title("Usage(Covid_related) Contribution of Groups with Differnet CareSysCondition ",fontsize=20)
# Use countplot and give an order by count activity use time
sns.countplot(x='CareSysCondition', data=Care_data, order = Care_data['CareSysCondition'].value_counts().index)
# Out:
# <AxesSubplot:title={'center':'Usage(Covid_related) Contribution of Groups with Differnet CareSysCondition '}, xlabel='CareSysCondition', ylabel='count'>

# %% [markdown]
# ### Key finding:
# - It shows that group with `arthritis` contributes an overwhelming number of `'Care'-related usage`. To makes sure it is not only because that group with arthritis contribute most on `the total usage`, I use the figure below to show the total usage contribution grouped by CareSysCondition.

# %%
sns.set(style='darkgrid',palette='pastel')
plt.figure(figsize=(16,9),dpi=100)
plt.xticks(rotation=75)
plt.title("Usage(Total) Contribution of Groups with different differnet CareSysCondition",fontsize=20)
# Use countplot and give an order by count activity use time
sns.countplot(x='CareSysCondition', data=Time_Condition_data_no_unknown, order = Time_Condition_data_no_unknown['CareSysCondition'].value_counts().index)
# Out:
# <AxesSubplot:title={'center':'Usage(Total) Contribution of Groups with different differnet CareSysCondition'}, xlabel='CareSysCondition', ylabel='count'>

# %% [markdown]
# ### Key Findings:
# - Group with `Arthritis` clicks most on `LinkTitle` `with the keyword 'Care'`, which contributes an overwhelming Usage of `Care`-related activity.
# - Group with `Cerebral Palsy` has a very similar level of `Total usage` with Group with `Arthritis`, but its contribution in `Care`-related activity usage is much more less than Group with `Arthritis`.
# - It might because that the `function` in Care-related activity is more suitable for or it originally target at users with `Arthritis` than users with `Cerebral Palsy`.
#
# ### Potential Uses of Code:
# This code will also equally work well by changing the Keyword `'Care'`.
# For example, change it to `'Covid'`, so we could find users with what condition concerns more about Covid.

# %% [markdown]
# ## 2.6 Age feature in Activities (in `'Category'` `Link Type`)
# ### Hypothesis:
# - Different `Age` users might have different activity preferences.

# %%
Category_data = Time_Condition_data.loc[Time_Condition_data['LinkType']=='Category']

# Data being group by CareSysCondition, to explore the age distribution in each group(CareSysCondition)
group_LinkTitle = Category_data.groupby('LinkTitle')

# to give an order for different'CareSysCondition' by the average age
avg_age_forLinkTitle = group_LinkTitle.agg({'Age':np.mean}).sort_values('Age')

plt.figure(figsize=(16,9),dpi=200)
sns.set(style='darkgrid',font_scale=0.8,palette='pastel')
sns.boxplot(x='LinkTitle', y='Age', data=Category_data, order = avg_age_forLinkTitle.index)
plt.xticks(rotation=75,fontsize=8)
plt.yticks(fontsize=10)
plt.title('Age distribution for Activities',fontsize=20)
plt.show()

# %% [markdown]
# **Key findings:**
# * Some Activities has Age feature, which means that the Age Distribution of those activities is relatively concentrite, and without extreme Age value.(e.g. Digital Skills, Covid Information and Covid Dundee...)
# * `All` clicking relates to `Covid` are on the far right of x axis of this figure:
#     * The x axis is sort by the average age of each group —— old people(between 60 and 85) concers more about Covid.
#     * No exterme value over 100 or less than 50 in Covid-related clicking —— Younger or older people are not very concerned about covid(at least in CleverCogs)

# %% [markdown]
# # Part III: Reflect and Hypothesise
#
# ### Reflection on potential causes behind the data and how it might relate to the world:
#
# The Countplot in Explore 2.1 shows that the overall trend of `Care-related Activity` Usage is up which might refer to that as the Progress of Covid and lockdown, people might be likely to become more concerned about their health so that will check their care status and pay attention to care information more frequently.
#
# The Boxplot of Explore 2.2 shows that within CleverCogs users, the `Age Distribution` of some groups (with specific `Care System Condition`) is relatively `concentrated` and without extreme age value, which means these groups have `Age Feature`, for example, the age range of the the group with Parkinsons is from 60 to 100. Although the data is from CleverCogs users, This might reflect the age feature that specific condition among all people with that condition.
#
# Besides the possible `Age` feature shown in the Boxplot of Explore 2.6 which might refer to that user of different `Age` might have different `activity preferences`, an important finding is that `All` usage relates to `Covid` are on the far right of the x-axis(which is sorted by the average age of each group) of this figure, which refers to that older people(between 60 and 85) concerns more about Covid than younger people.
#
# The Pie chart in Explore 2.5 shows that Group with `Arthritis` contributes an overwhelming amount on care-related usage, and meanwhile, group with `Cerebral Palsy`, which has a very similar level of `Total usage` with Group with `Arthritis`, contributed much less in `Care-related activity` usage than Group with `Arthritis`. It might refer to that the `function` in Care-related activity is more suitable for users with `Arthritis` than users with `Cerebral Palsy`, or the information in it is more helpful for users with `Arthritis`.
#
#
#
#
#
#
#
# ## Hypotheses
# **Hypothesis 1**: Impacted by Covid, people might be likely to care less about their recreational activities and more about their health.
#
# - **Why I think that**: based on Explore 2.1 `Activities Usage from 2018 to 2021`, I got the trend of the total usage and the usage of  `Entertainment` and `Care`-related activity. The overall trend is down before lockdown (2018-2019), and is up during lockdown (2020-2021); At the same time, the trend of `Entertainment` Usage is down throughout the period from 2018 to 2021, and the `overall usage` of `Entertainment `during lockdown is less than the overall usage before lockdown; However, the overall trend of `Care`-related Activity Usage is up.
#
# - **How to test**: Group the `Link Title` by **recreational activities** and **health-related activities**, and see the Usage of these two groups.
#
# ---
#
#
# **Hypothesis 2**: Care System Condition will affact the Gender Contribution Ratio in Usage.
#
# For example, in the group with `Arthritis`, the female is actively contributed in usage while males never contributed. However if we change the `CareSysCondition` to `Cerebral Palsy`, in the group with `Cerebral Palsy`, the male contributes more actively than female.
#
#
# - **Why I think that**: Referring Explore 2.4 `Gender Contribution in Usage with different Care System Condition`, for group with `Arthritis`：There is 30.43% Male and 69.57% female in that group; However, the contribution of usage of female is 74.24%, and that of male is 25.73; For group with `Cerebral Palsy`：There is 60.9% Male and 38.1% female in that group; However, the contribution of usage of Male is far over 60.9%, which is 94.58%.
#
# - **How to test**: Analysis every group individually, go through other columns to see is there any other variable that affacts Gender Contribution Ratio in Usage.
#
# ---
#
#
# **Hypothesis 3**: Groups with different CareSysCondition might have varying contribution ratio in different activity usage, and it might because some activity or function itself is more suitable for group with specific conditions.
#
# - **Why I think that**: Referring Explore 2.5 `User Care System Condition and 'Care'-related Activities`, Group with `Arthritis` clicks most on `LinkTitle` `with the keyword 'Care'`, which contributes an overwhelming Usage of `Care`-related activities; Meanwhile, Group with `Cerebral Palsy` has a very similar level of `Total usage` with Group with `Arthritis`, but its contribution in `Care`-related activity usage is much less than Group with `Arthritis`. It might be because that the `function` in Care-related activity is more suitable for or it originally target at users with `Arthritis` than users with `Cerebral Palsy`.
#
# - **How to test**: Go through other keywords(e.g. `music`, `radio`, `Game` ), and see the usage contribution of each group (with different care system conditions).
#
#
# ---
#
# **Hypothesis 4**: There is a group or groups with specific care system conditions that are more active on `'Covid'`-related activities.
#
# - **Why I think that**: Referring Explore 2.5 `User Care System Condition and 'Care'-related Activities`, I've already got the `Usage Contribution(Care-related) with different CareSysCondition` and `Usage Contribution(Total) with different CareSysCondition`, and find the overwhelming contribution of the group with `Arthritis` in care-related activity.
#
# - **How to test**: Change the keyword of `Care` to `Covid`, sort out covid-related activities and see the usage contribution of each group (with different care system conditions).

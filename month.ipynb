# %% [markdown]
# # Does the frequency of user use of the function change from month to month?

# %% [raw]
# # Split data by month. Discover what features users are more likely to use in the system between July and November, and what is the difference in usage between those months

# %%
#Deploy the environment and import the analysis package and data
import os    
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
import warnings

# %%
style.use('seaborn')
warnings.filterwarnings('ignore')

# %% [markdown]
# # CCDate11m5-7m4.xlsx

# %%
#Import data and view the scale and complex
data1 = pd.read_excel('./CCDate11m5-7m4.xlsx')
data1

data1_ = data1[data1['Role'] == 'User']#Only user data is retained
data1_.dropna(subset=['ExternalID'],inplace=True)
data1_.index = range(data1_.shape[0])
data1_

data1_['Time'] = data1['Time'].dt.month
data1_.groupby(['Time','Link  Type']).count()['VisitorID'].plot(kind='bar',figsize=(10,8))
plt.xlabel('')
plt.title('Distribution of different activities in different time slot')
plt.show()

# %% [markdown]
# # CCDate12.1.20-1.5.21.xlsx

# %%
data1 = pd.read_excel('./CCDate12.1.20-1.5.21.xlsx')
data1

data1_ = data1[data1['Role'] == 'User']#Only user data is retained
data1_.dropna(subset=['ExternalID'],inplace=True)
data1_.index = range(data1_.shape[0])
data1_

data1_['Time'] = data1['Time'].dt.month
data1_.groupby(['Time','Link  Type']).count()['VisitorID'].plot(kind='bar',figsize=(10,8))
plt.xlabel('')
plt.title('Distribution of different activities in different time slot')
plt.show()

# %% [markdown]
# # CCDate_11.5.20-12.1.20.xlsx

# %%
data1 = pd.read_excel('./CCDate_11.5.20-12.1.20.xlsx')
data1

data1 = pd.read_excel('./CCDate12.1.20-1.5.21.xlsx')
data1

data1_ = data1[data1['Role'] == 'User']#Only user data is retained
data1_.dropna(subset=['ExternalID'],inplace=True)
data1_.index = range(data1_.shape[0])
data1_

data1_['Time'] = data1['Time'].dt.month
data1_.groupby(['Time','Link  Type']).count()['VisitorID'].plot(kind='bar',figsize=(10,8))
plt.xlabel('')
plt.title('Distribution of different activities in different time slot')
plt.show()

# %% [markdown]
# # CCDate_3.23.20-07.24.20-01.06.21- 03.08.21.csv

# %%
data1 = pd.read_excel('./CCDate12.1.20-1.5.21.xlsx')
data1

data1_ = data1[data1['Role'] == 'User']#Only user data is retained
data1_.dropna(subset=['ExternalID'],inplace=True)
data1_.index = range(data1_.shape[0])
data1_

data1_['Time'] = data1['Time'].dt.month
data1_.groupby(['Time','Link  Type']).count()['VisitorID'].plot(kind='bar',figsize=(10,8))
plt.xlabel('')
plt.title('Distribution of different activities in different time slot')
plt.show()

# %% [markdown]
# # CCDate2018-2021.xlsx

# %%
data1 = pd.read_excel('./CCDate2018-2021.xlsx')
data1

data1_ = data1[data1['Role'] == 'User']#Only user data is retained
data1_.dropna(subset=['ExternalID'],inplace=True)
data1_.index = range(data1_.shape[0])
data1_

data1_['Time'] = data1['Time'].dt.month
data1_.groupby(['Time','Link  Type']).count()['VisitorID'].plot(kind='bar',figsize=(20,8))
plt.xlabel('')
plt.title('Distribution of different activities in different time slot')
plt.show()
